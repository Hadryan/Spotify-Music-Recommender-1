# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
from tqdm import tqdm
import pandas as pd

# %%
client_id = 'xxxx' # replace with your client id from spotify web api dashboard
client_secret = 'xxxx' # replace with your client secret from spotify web api dashboard

# %%
# create empty lists where the results are going to be stored
artist_name = []
track_name = []
popularity = []
track_id = []

# %%
scope = 'user-top-read'
sp = spotipy.Spotify(
    auth_manager=SpotifyOAuth(
        client_id=client_id, 
        client_secret=client_secret, 
        scope=scope, 
        redirect_uri='https://localhost/' # add this to your application under redirect URIs
    )
)

ranges = ['short_term', 'medium_term', 'long_term']

for sp_range in ranges:
    print("range:", sp_range)
    results = sp.current_user_top_tracks(time_range=sp_range, limit=50)
    for i, item in enumerate(results['items']):
        artist_name.append(item['artists'][0]['name'])
        track_name.append(item['name'])
        track_id.append(item['id'])
        popularity.append(item['popularity'])
# Out:
# range: short_term
# range: medium_term
# range: long_term

# %%
years = ['2015', '2016', '2017', '2018', '2019', '2020', '2021']
for year in years:
    for i in tqdm(range(0, 1000, 50)):
        track_results = sp.search(q=f'year:{year}', type='track', limit=50, offset=i)
        for i, t in enumerate(track_results['tracks']['items']):
            artist_name.append(t['artists'][0]['name'])
            track_name.append(t['name'])
            track_id.append(t['id'])
            popularity.append(t['popularity'])
# Out:
# 100%|██████████| 20/20 [00:05<00:00,  3.77it/s]
# 100%|██████████| 20/20 [00:05<00:00,  3.53it/s]
# 100%|██████████| 20/20 [00:05<00:00,  3.55it/s]
# 100%|██████████| 20/20 [00:05<00:00,  3.60it/s]
# 100%|██████████| 20/20 [00:05<00:00,  3.36it/s]
# 100%|██████████| 20/20 [00:05<00:00,  3.68it/s]
# 100%|██████████| 20/20 [00:05<00:00,  3.48it/s]

# %% [markdown]
# ## ***Getting My top artists***

# %%
top_artists_name = []
top_artist_uri = []
for sp_range in ['short_term', 'medium_term', 'long_term']:
    print("range:", sp_range)

    results = sp.current_user_top_artists(time_range=sp_range, limit=50)

    for item in results['items']:
        top_artists_name.append(item['name'])
        top_artist_uri.append(item['uri'])

print(top_artists_name)
print(top_artist_uri)
# Out:
# range: short_term
# range: medium_term
# range: long_term
# ['Yuvan Shankar Raja', 'BTS', 'Ariana Grande', 'BLACKPINK', 'Tippu', 'A.R. Rahman', 'Doja Cat', 'TWICE', 'Anirudh Ravichander', 'Ariana Grande', 'Anirudh Ravichander', 'BTS', 'Yuvan Shankar Raja', 'BLACKPINK', 'A.R. Rahman', 'Tippu', 'Doja Cat', 'Olivia Rodrigo', 'Justin Bieber', 'Hwa Sa', 'TWICE', 'Harris Jayaraj', 'Ariana Grande', 'BLACKPINK', 'BTS', 'Anirudh Ravichander', 'TWICE', 'A.R. Rahman', 'Hwa Sa', 'Justin Bieber', 'Olivia Rodrigo', 'The Weeknd', 'Yuvan Shankar Raja', 'Dua Lipa', 'SOMI', 'Tippu', 'MAMAMOO', '24kGoldn', 'Doja Cat', 'Billie Eilish', 'Lady Gaga', 'Taylor Swift', 'Ed Sheeran', 'Harish Raghavendra', 'Karthik', 'Hariharan', 'One Direction', 'Hiphop Tamizha', 'Harris Jayaraj', 'Sam C.S.', 'Sid Sriram', 'Troye Sivan']
# ['spotify:artist:6AiX12wXdXFoGJ2vk8zBjy', 'spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX', 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR', 'spotify:artist:41MozSoPIsD1dJM0CLPjZF', 'spotify:artist:0PykiHCcDsMPRV7s67qZ1B', 'spotify:artist:1mYsTxnqsietFxj1OgoGbG', 'spotify:artist:5cj0lLjcoR7YOSnhnX0Po5', 'spotify:artist:7n2Ycct7Beij7Dj7meI4X0', 'spotify:artist:4zCH9qm4R2DADamUHMCa6O', 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR', 'spotify:artist:4zCH9qm4R2DADamUHMCa6O', 'spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX', 'spotify:artist:6AiX12wXdXFoGJ2vk8zBjy', 'spotify:artist:41MozSoPIsD1dJM0CLPjZF', 'spotify:artist:1mYsTxnqsietFxj1OgoGbG', 'spotify:artist:0PykiHCcDsMPRV7s67qZ1B', 'spotify:artist:5cj0lLjcoR7YOSnhnX0Po5', 'spotify:artist:1McMsnEElThX1knmY4oliG', 'spotify:artist:1uNFoZAHBGtllmzznpCI3s', 'spotify:artist:7bmYpVgQub656uNTu6qGNQ', 'spotify:artist:7n2Ycct7Beij7Dj7meI4X0', 'spotify:artist:29aw5YCdIw2FEXYyAJZI8l', 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR', 'spotify:artist:41MozSoPIsD1dJM0CLPjZF', 'spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX', 'spotify:artist:4zCH9qm4R2DADamUHMCa6O', 'spotify:artist:7n2Ycct7Beij7Dj7meI4X0', 'spotify:artist:1mYsTxnqsietFxj1OgoGbG', 'spotify:artist:7bmYpVgQub656uNTu6qGNQ', 'spotify:artist:1uNFoZAHBGtllmzznpCI3s', 'spotify:artist:1McMsnEElThX1knmY4oliG', 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ', 'spotify:artist:6AiX12wXdXFoGJ2vk8zBjy', 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we', 'spotify:artist:7zYj9S9SdIunYCfSm7vzAR', 'spotify:artist:0PykiHCcDsMPRV7s67qZ1B', 'spotify:artist:0XATRDCYuuGhk0oE7C0o5G', 'spotify:artist:6fWVd57NKTalqvmjRd2t8Z', 'spotify:artist:5cj0lLjcoR7YOSnhnX0Po5', 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH', 'spotify:artist:1HY2Jd0NmPuamShAr6KMms', 'spotify:artist:06HL4z0CvFAxyc27GXpf02', 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V', 'spotify:artist:4Kw0NhqitzjxLy1jH5FlTg', 'spotify:artist:0LSPREIgGMZXCuKVel7LVD', 'spotify:artist:2NoJ7NuNs9nyj8Thoh1kbu', 'spotify:artist:4AK6F7OLvEQ5QYCBNiQWHq', 'spotify:artist:7zFBW2JxM4bgTTKxCRcS8Q', 'spotify:artist:29aw5YCdIw2FEXYyAJZI8l', 'spotify:artist:5VAyiDhBinVfc6RM5RKnLa', 'spotify:artist:7qjJw7ZM2ekDSahLXPjIlN', 'spotify:artist:3WGpXCj9YhhfX11TToZcXP']

# %% [markdown]
# ## ***Getting top songs of my top artists***

# %%
for artist, uri in tqdm(zip(top_artists_name, top_artist_uri), total=len(top_artist_uri)):
    response = sp.artist_top_tracks(uri, country='IN')
    for track in response['tracks']:
        artist_name.append(artist)
        track_name.append(track['name'])
        track_id.append(track['id'])
        popularity.append(track['popularity'])
# Out:
# 100%|██████████| 52/52 [00:06<00:00,  8.33it/s]

# %%
print('number of elements in the track_id list:', len(track_id))
# Out:
# number of elements in the track_id list: 7667

# %%
df_tracks = pd.DataFrame(
    {
        'artist_name': artist_name,
        'track_name':track_name,
        'track_id':track_id,
        'popularity':popularity
    }
)
print(df_tracks.shape)
df_tracks
# Out:
# (7667, 4)
#       artist_name                           track_name  \
# 0            SOMI                            DUMB DUMB
# 1         ENHYPEN                                FEVER
# 2            LISA                               LALISA
# 3           SUSHI                    Naruto Main Theme
# 4            LISA                                MONEY
# ...           ...                                  ...
# 7662  Troye Sivan                                YOUTH
# 7663  Troye Sivan                        There for You
# 7664  Troye Sivan  Dance To This (feat. Ariana Grande)
# 7665  Troye Sivan                            My My My!
# 7666  Troye Sivan     could cry just thinkin about you
#
#                     track_id  popularity
# 0     6dG2zPUOWXk3eMC7Hb3wh3          75
# 1     0UzymivvUH5s8z4PeWZJaK          82
# 2     2KZ3sNqPogEyMUUH6A5HFy          86
# 3     4SWBuoXEtpFW0JfZTWgYkq          43
# 4     45OX2jjEw1l7lOFJfDP9fv          86
# ...                      ...         ...
# 7662  0nhBKubnVz9yFNNprBniWz          71
# 7663  6jA8HL9i4QGzsj6fjoxp8Y          69
# 7664  2NjO87HyT80fsgejd3PLYW          69
# 7665  4NiehSBQthimPzRsVeOgCT          68
# 7666  3H7oAhHxkEkSf9iomv2mbG          68
#
# [7667 rows x 4 columns]

# %%
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7667 entries, 0 to 7666
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   artist_name  7667 non-null   object
#  1   track_name   7667 non-null   object
#  2   track_id     7667 non-null   object
#  3   popularity   7667 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 239.7+ KB

# %%
grouped = df_tracks.groupby(['artist_name','track_name'], as_index=True).size()
grouped[grouped > 1].count()
# Out:
# 554

# %%
df_tracks.drop_duplicates(subset=['artist_name','track_name'], inplace=True)

# %%
grouped_after_dropping = df_tracks.groupby(['artist_name','track_name'], as_index=True).size()
grouped_after_dropping[grouped_after_dropping > 1].count()
# Out:
# 0

# %%
df_tracks.shape
# Out:
# (6640, 4)

# %%
# empty list, batchsize and the counter for None results
rows = []
batchsize = 100
None_counter = 0

for i in range(0,len(df_tracks['track_id']),batchsize):
    batch = df_tracks['track_id'][i: i+batchsize]
    feature_results = sp.audio_features(batch)
    for i, t in enumerate(feature_results):
        if t == None:
            None_counter = None_counter + 1
        else:
            rows.append(t)
            
print('Number of tracks where no audio features were available:', None_counter)
# Out:
# Number of tracks where no audio features were available: 6

# %%
print('number of elements in the track_id list:', len(rows))
# Out:
# number of elements in the track_id list: 6634

# %%
audio_features_df = pd.DataFrame.from_dict(rows, orient='columns')
print("Shape of the dataset:", audio_features_df.shape)
audio_features_df
# Out:
# Shape of the dataset: (6634, 18)
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.850   0.734    2    -6.415     1       0.0491       0.02210
# 1            0.600   0.713    6    -5.079     0       0.0592       0.06420
# 2            0.804   0.652    8    -6.282     1       0.0898       0.02670
# 3            0.581   0.773    9    -5.588     0       0.0276       0.00258
# 4            0.826   0.553    1   -10.121     0       0.2340       0.16300
# ...            ...     ...  ...       ...   ...          ...           ...
# 6629         0.581   0.674    8    -7.090     1       0.0330       0.00187
# 6630         0.611   0.644    6    -7.607     0       0.0553       0.12400
# 6631         0.736   0.756   11    -7.099     1       0.0470       0.00632
# 6632         0.701   0.458    1    -7.749     1       0.0836       0.00407
# 6633         0.515   0.323    6   -11.050     1       0.0429       0.31800
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000179    0.0728   0.4060  103.027  audio_features
# 1             0.000000    0.1420   0.4710   72.999  audio_features
# 2             0.000782    0.1180   0.8540  150.076  audio_features
# 3             0.001910    0.3260   0.0977  104.970  audio_features
# 4             0.000041    0.1350   0.4000  140.037  audio_features
# ...                ...       ...      ...      ...             ...
# 6629          0.000003    0.1280   0.4880  143.005  audio_features
# 6630          0.000000    0.1240   0.1300  105.969  audio_features
# 6631          0.005770    0.1060   0.7120  117.016  audio_features
# 6632          0.000151    0.0450   0.4820  102.967  audio_features
# 6633          0.000000    0.1060   0.1880  147.972  audio_features
#
#                           id                                   uri  \
# 0     6dG2zPUOWXk3eMC7Hb3wh3  spotify:track:6dG2zPUOWXk3eMC7Hb3wh3
# 1     0UzymivvUH5s8z4PeWZJaK  spotify:track:0UzymivvUH5s8z4PeWZJaK
# 2     2KZ3sNqPogEyMUUH6A5HFy  spotify:track:2KZ3sNqPogEyMUUH6A5HFy
# 3     4SWBuoXEtpFW0JfZTWgYkq  spotify:track:4SWBuoXEtpFW0JfZTWgYkq
# 4     45OX2jjEw1l7lOFJfDP9fv  spotify:track:45OX2jjEw1l7lOFJfDP9fv
# ...                      ...                                   ...
# 6629  4XWaUb7mKRcJR5RPp4IIDr  spotify:track:4XWaUb7mKRcJR5RPp4IIDr
# 6630  6jA8HL9i4QGzsj6fjoxp8Y  spotify:track:6jA8HL9i4QGzsj6fjoxp8Y
# 6631  2NjO87HyT80fsgejd3PLYW  spotify:track:2NjO87HyT80fsgejd3PLYW
# 6632  4NiehSBQthimPzRsVeOgCT  spotify:track:4NiehSBQthimPzRsVeOgCT
# 6633  3H7oAhHxkEkSf9iomv2mbG  spotify:track:3H7oAhHxkEkSf9iomv2mbG
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/6dG2zPUOWXk3...
# 1     https://api.spotify.com/v1/tracks/0UzymivvUH5s...
# 2     https://api.spotify.com/v1/tracks/2KZ3sNqPogEy...
# 3     https://api.spotify.com/v1/tracks/4SWBuoXEtpFW...
# 4     https://api.spotify.com/v1/tracks/45OX2jjEw1l7...
# ...                                                 ...
# 6629  https://api.spotify.com/v1/tracks/4XWaUb7mKRcJ...
# 6630  https://api.spotify.com/v1/tracks/6jA8HL9i4QGz...
# 6631  https://api.spotify.com/v1/tracks/2NjO87HyT80f...
# 6632  https://api.spotify.com/v1/tracks/4NiehSBQthim...
# 6633  https://api.spotify.com/v1/tracks/3H7oAhHxkEkS...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/6dG2...       149214
# 1     https://api.spotify.com/v1/audio-analysis/0Uzy...       172107
# 2     https://api.spotify.com/v1/audio-analysis/2KZ3...       200690
# 3     https://api.spotify.com/v1/audio-analysis/4SWB...       137143
# 4     https://api.spotify.com/v1/audio-analysis/45OX...       168228
# ...                                                 ...          ...
# 6629  https://api.spotify.com/v1/audio-analysis/4XWa...       213572
# 6630  https://api.spotify.com/v1/audio-analysis/6jA8...       221904
# 6631  https://api.spotify.com/v1/audio-analysis/2NjO...       231847
# 6632  https://api.spotify.com/v1/audio-analysis/4Nie...       204727
# 6633  https://api.spotify.com/v1/audio-analysis/3H7o...       158001
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 6629               4
# 6630               4
# 6631               4
# 6632               4
# 6633               4
#
# [6634 rows x 18 columns]

# %%
audio_features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6634 entries, 0 to 6633
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      6634 non-null   float64
#  1   energy            6634 non-null   float64
#  2   key               6634 non-null   int64
#  3   loudness          6634 non-null   float64
#  4   mode              6634 non-null   int64
#  5   speechiness       6634 non-null   float64
#  6   acousticness      6634 non-null   float64
#  7   instrumentalness  6634 non-null   float64
#  8   liveness          6634 non-null   float64
#  9   valence           6634 non-null   float64
#  10  tempo             6634 non-null   float64
#  11  type              6634 non-null   object
#  12  id                6634 non-null   object
#  13  uri               6634 non-null   object
#  14  track_href        6634 non-null   object
#  15  analysis_url      6634 non-null   object
#  16  duration_ms       6634 non-null   int64
#  17  time_signature    6634 non-null   int64
# dtypes: float64(9), int64(4), object(5)
# memory usage: 933.0+ KB

# %%
columns_to_drop = ['analysis_url', 'track_href', 'type', 'uri']
audio_features_df.drop(columns_to_drop, axis=1,inplace=True)

audio_features_df.rename(columns={'id': 'track_id'}, inplace=True)

audio_features_df.shape
# Out:
# (6634, 14)

# %%
# merge both dataframes
# the 'inner' method will make sure that we only keep track IDs present in both datasets
df = pd.merge(df_tracks, audio_features_df, on='track_id', how='inner')
df
# Out:
#       artist_name                                     track_name  \
# 0            SOMI                                      DUMB DUMB
# 1         ENHYPEN                                          FEVER
# 2            LISA                                         LALISA
# 3           SUSHI                              Naruto Main Theme
# 4            LISA                                          MONEY
# ...           ...                                            ...
# 6677  Troye Sivan                                     Angel Baby
# 6678  Troye Sivan  Easy (with Kacey Musgraves feat. Mark Ronson)
# 6679  Troye Sivan            Dance To This (feat. Ariana Grande)
# 6680  Troye Sivan                                      My My My!
# 6681  Troye Sivan               could cry just thinkin about you
#
#                     track_id  popularity  danceability  energy  key  loudness  \
# 0     6dG2zPUOWXk3eMC7Hb3wh3          75         0.850   0.734    2    -6.415
# 1     0UzymivvUH5s8z4PeWZJaK          82         0.600   0.713    6    -5.079
# 2     2KZ3sNqPogEyMUUH6A5HFy          86         0.804   0.652    8    -6.282
# 3     4SWBuoXEtpFW0JfZTWgYkq          43         0.581   0.773    9    -5.588
# 4     45OX2jjEw1l7lOFJfDP9fv          86         0.826   0.553    1   -10.121
# ...                      ...         ...           ...     ...  ...       ...
# 6677  2m6Ko3CY1qXNNja8AlugNc          79         0.559   0.559   11    -6.425
# 6678  4XWaUb7mKRcJR5RPp4IIDr          72         0.581   0.674    8    -7.090
# 6679  2NjO87HyT80fsgejd3PLYW          69         0.736   0.756   11    -7.099
# 6680  4NiehSBQthimPzRsVeOgCT          68         0.701   0.458    1    -7.749
# 6681  3H7oAhHxkEkSf9iomv2mbG          68         0.515   0.323    6   -11.050
#
#       mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0        1       0.0491       0.02210          0.000179    0.0728   0.4060
# 1        0       0.0592       0.06420          0.000000    0.1420   0.4710
# 2        1       0.0898       0.02670          0.000782    0.1180   0.8540
# 3        0       0.0276       0.00258          0.001910    0.3260   0.0977
# 4        0       0.2340       0.16300          0.000041    0.1350   0.4000
# ...    ...          ...           ...               ...       ...      ...
# 6677     1       0.0358       0.01450          0.000000    0.1380   0.3380
# 6678     1       0.0330       0.00187          0.000003    0.1280   0.4880
# 6679     1       0.0470       0.00632          0.005770    0.1060   0.7120
# 6680     1       0.0836       0.00407          0.000151    0.0450   0.4820
# 6681     1       0.0429       0.31800          0.000000    0.1060   0.1880
#
#         tempo  duration_ms  time_signature
# 0     103.027       149214               4
# 1      72.999       172107               4
# 2     150.076       200690               4
# 3     104.970       137143               4
# 4     140.037       168228               4
# ...       ...          ...             ...
# 6677   72.498       220780               4
# 6678  143.005       213572               4
# 6679  117.016       231847               4
# 6680  102.967       204727               4
# 6681  147.972       158001               4
#
# [6682 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6682 entries, 0 to 6681
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist_name       6682 non-null   object
#  1   track_name        6682 non-null   object
#  2   track_id          6682 non-null   object
#  3   popularity        6682 non-null   int64
#  4   danceability      6682 non-null   float64
#  5   energy            6682 non-null   float64
#  6   key               6682 non-null   int64
#  7   loudness          6682 non-null   float64
#  8   mode              6682 non-null   int64
#  9   speechiness       6682 non-null   float64
#  10  acousticness      6682 non-null   float64
#  11  instrumentalness  6682 non-null   float64
#  12  liveness          6682 non-null   float64
#  13  valence           6682 non-null   float64
#  14  tempo             6682 non-null   float64
#  15  duration_ms       6682 non-null   int64
#  16  time_signature    6682 non-null   int64
# dtypes: float64(9), int64(5), object(3)
# memory usage: 939.7+ KB

# %% [markdown]
# ## ***Final check for duplicates.***

# %%
df[df.duplicated(subset=['artist_name', 'track_name'], keep=False)]
# Out:
#              artist_name                                    track_name  \
# 54            The Weeknd  Save Your Tears (with Ariana Grande) (Remix)
# 55            The Weeknd  Save Your Tears (with Ariana Grande) (Remix)
# 56         Ariana Grande  Save Your Tears (with Ariana Grande) (Remix)
# 57         Ariana Grande  Save Your Tears (with Ariana Grande) (Remix)
# 209             Dua Lipa                              Kiss and Make Up
# ...                  ...                                           ...
# 6594           Hariharan                                  Thodu Vaanam
# 6596      Harris Jayaraj                             Naaloney Pongaynu
# 6597      Harris Jayaraj                             Naaloney Pongaynu
# 6598  Harish Raghavendra                             Naaloney Pongaynu
# 6599  Harish Raghavendra                             Naaloney Pongaynu
#
#                     track_id  popularity  danceability  energy  key  loudness  \
# 54    37BZB0z9T8Xu7U3e65qxFy          91         0.650   0.825    0    -4.645
# 55    37BZB0z9T8Xu7U3e65qxFy          91         0.650   0.825    0    -4.645
# 56    37BZB0z9T8Xu7U3e65qxFy          91         0.650   0.825    0    -4.645
# 57    37BZB0z9T8Xu7U3e65qxFy          91         0.650   0.825    0    -4.645
# 209   13hvHEstJ4sNbzdroPrPI3          55         0.675   0.729    8    -4.383
# ...                      ...         ...           ...     ...  ...       ...
# 6594  4HDzsx1dJKbuL0YkffBuBm          54         0.628   0.551    0    -6.841
# 6596  2bageubuN1HjNZwTNlyh0v          54         0.714   0.495    9    -7.226
# 6597  2bageubuN1HjNZwTNlyh0v          54         0.714   0.495    9    -7.226
# 6598  2bageubuN1HjNZwTNlyh0v          54         0.714   0.495    9    -7.226
# 6599  2bageubuN1HjNZwTNlyh0v          54         0.714   0.495    9    -7.226
#
#       mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 54       1       0.0325        0.0215          0.000024    0.0936    0.593
# 55       1       0.0325        0.0215          0.000024    0.0936    0.593
# 56       1       0.0325        0.0215          0.000024    0.0936    0.593
# 57       1       0.0325        0.0215          0.000024    0.0936    0.593
# 209      1       0.1460        0.0557          0.000000    0.1890    0.630
# ...    ...          ...           ...               ...       ...      ...
# 6594     0       0.0612        0.3940          0.000000    0.1780    0.385
# 6596     1       0.0361        0.3280          0.000000    0.1040    0.238
# 6597     1       0.0361        0.3280          0.000000    0.1040    0.238
# 6598     1       0.0361        0.3280          0.000000    0.1040    0.238
# 6599     1       0.0361        0.3280          0.000000    0.1040    0.238
#
#         tempo  duration_ms  time_signature
# 54    118.091       191014               4
# 55    118.091       191014               4
# 56    118.091       191014               4
# 57    118.091       191014               4
# 209    99.986       190560               4
# ...       ...          ...             ...
# 6594  136.899       315213               4
# 6596  114.979       372600               4
# 6597  114.979       372600               4
# 6598  114.979       372600               4
# 6599  114.979       372600               4
#
# [96 rows x 17 columns]

# %% [markdown]
# ## ***Dropping all the duplicates***

# %%
df.drop_duplicates(subset=['artist_name','track_name'], inplace=True)
df[df.duplicated(subset=['artist_name', 'track_name'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [artist_name, track_name, track_id, popularity, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, duration_ms, time_signature]
# Index: []

# %%
df.shape
# Out:
# (6634, 17)

# %%
df.to_csv('../data/spotify_audio_features.csv', index=False)
